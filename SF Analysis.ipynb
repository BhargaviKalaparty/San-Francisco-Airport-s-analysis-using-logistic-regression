# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
sb.set_theme(style='ticks')
from patsy import dmatrices
ij = pd.read_csv(r"C:\Users\Bhargavi Kalaparty\Downloads\assignment-2-k2175468 (1).csv")
ij.head()
# Out:
#    good  dirty  wait  lastyear  usa
# 0     0      0  5.19         2    1
# 1     1      0  0.36         1    1
# 2     0      0  0.86         1    1
# 3     1      0  1.11         1    1
# 4     1      0  0.61         4    1

# %%
import matplotlib.pyplot as plt

# %%
ij.plot(kind=density,
        figsize(10,10));
# Out:
#   Input In [10]
#     figsize(10,10));
#                   ^
# SyntaxError: positional argument follows keyword argument

# %%
ij.mean()
# Out:
# good        0.584771
# dirty       0.092851
# wait        2.435839
# lastyear    3.945768
# usa         0.755683
# dtype: float64

# %%
ij.median()
# Out:
# good        1.00
# dirty       0.00
# wait        1.62
# lastyear    2.00
# usa         1.00
# dtype: float64

# %%
sns.displot(data=ij, x='lastyear', bins=2, kde=True, rug=True)

# %%
sns.displot(data=ij, x='good', bins=10, kde=True, rug=True)

# %%
sns.displot(data=df, x='dirty', bins=5, kde=True, rug=True)

# %%
sns.displot(data=df, x='usa', bins=10, kde=True, rug=True)

# %%
plt.figure(figsize=(3,7), dpi=200)
sns.boxplot(data=ij, y='lastyear')
# Out:
# <AxesSubplot:ylabel='lastyear'>

# %%
plt.figure(figsize=(3,7), dpi=200)
sns.boxplot(data=ij, y='dirty')
# Out:
# <AxesSubplot:ylabel='dirty'>

# %%
sns.displot(data=ij, x='wait', bins=10, kde=True, rug=True)

# %%
plt.hist(data=ij, x='wait');

# %%
plt.figure(figsize=(3,7), dpi=200)
sns.boxplot(data=ij, y='wait',showmeans=True)
# Out:
# <AxesSubplot:ylabel='wait'>

# %%
print(ij['good'].count());
with sns.axes_style('white'):
    df['good'].value_counts().plot.pie(autopct='%1.1f%%',figsize=(10,50),shadow=True,fontsize=15)
# Out:
# 3651

# %%
print(ij['dirty'].count());
with sns.axes_style('white'):
    df['dirty'].value_counts().plot.pie(autopct='%1.1f%%',figsize=(10,50),shadow=True,fontsize=15)
# Out:
# 3651

# %%
ij.value_counts('dirty')
# Out:
# dirty
# 0    3403
# 1     180
# 2      53
# 3      11
# 5       2
# 4       1
# 6       1
# dtype: int64

# %%
import statistics as stat

# %%
print(ij['usa'].count());
with sns.axes_style('white'):
    df['usa'].value_counts().plot.pie(autopct='%1.1f%%',figsize=(10,50),shadow=True,fontsize=15)
# Out:
# 3651

# %%
plt.figure(figsize=(3,7), dpi=200)
sns.boxplot(data=ij, y='wait', x='usa',showmeans=True, hue='good')
# Out:
# <AxesSubplot:xlabel='usa', ylabel='wait'>

# %%
np.round(ij.corr(),decimals=2)
# Out:
#           good  dirty  wait  lastyear   usa
# good      1.00  -0.13 -0.09     -0.02 -0.00
# dirty    -0.13   1.00  0.00      0.08  0.05
# wait     -0.09   0.00  1.00      0.06  0.10
# lastyear -0.02   0.08  0.06      1.00  0.08
# usa      -0.00   0.05  0.10      0.08  1.00
